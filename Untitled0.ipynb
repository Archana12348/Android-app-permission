# %% [markdown]
# <a href="https://colab.research.google.com/github/Archana12348/Archana12348/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-f046fe71-33ec-4d26-b56d-d73fbe7960a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f046fe71-33ec-4d26-b56d-d73fbe7960a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer  # <--- Changed import
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# Load the dataset
data = pd.read_csv("Android_Permission.csv")

# Identify columns with non-numeric data
non_numeric_cols = data.select_dtypes(include=['object']).columns

# Use LabelEncoder to convert non-numeric columns to numeric
le = LabelEncoder()
for col in non_numeric_cols:
    data[col] = le.fit_transform(data[col])

# Split the data into independent and dependent variables
X = data.iloc[:, 1:183]  # independent variables
y = data.iloc[:, 183:184]  # dependent variable

# Create a pipeline to handle NaN values and scale the data
pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # replace NaN with mean
    ('scaler', StandardScaler())
])

X_scaled = pipe.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train a Random Forest Classifier model
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = rfc.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Accuracy: 0.8028333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.69      0.70      1993
#            1       0.85      0.86      0.85      4007
#
#     accuracy                           0.80      6000
#    macro avg       0.78      0.78      0.78      6000
# weighted avg       0.80      0.80      0.80      6000
#
# Confusion Matrix:
# [[1381  612]
#  [ 571 3436]]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# Load the dataset
data = pd.read_csv("Android_Permission.csv")

# Identify columns with non-numeric data
non_numeric_cols = data.select_dtypes(include=['object']).columns

# Use LabelEncoder to convert non-numeric columns to numeric
le = LabelEncoder()
for col in non_numeric_cols:
    data[col] = le.fit_transform(data[col])

# Split the data into independent and dependent variables
X = data.iloc[:, 1:183]  # independent variables
y = data.iloc[:, 183:184]  # dependent variable

# Create a pipeline to handle NaN values and scale the data
pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # replace NaN with mean
    ('scaler', StandardScaler())
])

X_scaled = pipe.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train a Random Forest Classifier model
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(X_train, y_train)

# Simulate 100 users testing the app
num_users = 200
user_input_data = np.random.rand(num_users, 182)  # generate random input data for 100 users
user_input_data_scaled = pipe.transform(user_input_data)  # scale the input data

# Use the trained model to predict the output for each user
user_predictions = rfc.predict(user_input_data_scaled)

# Print the results
print("User Predictions:")
for i, prediction in enumerate(user_predictions):
    print(f"User {i+1}: {'Malicious' if prediction == 1 else 'Not Malicious'}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# User Predictions:
# User 1: Malicious
# User 2: Malicious
# User 3: Malicious
# User 4: Malicious
# User 5: Malicious
# User 6: Malicious
# User 7: Malicious
# User 8: Malicious
# User 9: Malicious
# User 10: Malicious
# User 11: Malicious
# User 12: Malicious
# User 13: Malicious
# User 14: Malicious
# User 15: Malicious
# User 16: Malicious
# User 17: Malicious
# User 18: Malicious
# User 19: Malicious
# User 20: Malicious
# User 21: Malicious
# User 22: Malicious
# User 23: Malicious
# User 24: Malicious
# User 25: Malicious
# User 26: Malicious
# User 27: Malicious
# User 28: Malicious
# User 29: Malicious
# User 30: Malicious
# User 31: Malicious
# User 32: Malicious
# User 33: Malicious
# User 34: Malicious
# ...
